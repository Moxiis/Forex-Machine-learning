# %%
import pandas as pd

# %%
forex_data = pd.read_feather("data/forex_data.feather")
forex_sample = forex_data.head()

# %%
# save to csv
forex_sample.to_csv("data/forex_data_sample.csv", index=False)
